# %%
#Import packages
import math
import numpy as np
import os
import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import colors
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import scale

# %%
#Load file
def parse_file(name):
    data = []
    f = open(name,"r")
    line = f.readline().strip()
    try:
        line_list = list(map(float, [x for x in line.split(',')]))
        data.append(line_list)
    except ValueError: #Remove cases where we cant read data
        print("A line "+ line +" could not be parsed")
    while(line):
        line = f.readline().strip()
        try:
            line_list = list(map(float, [x for x in line.split(',')]))
            data.append(line_list)
        except ValueError:
            print("A line "+ line +" could not be parsed")
    f.close()
    return data

# %% [markdown]
#  # Linear regression

# %%
data = parse_file("ex1data1.mat")
X = np.array([x[0] for x in data])
#Reshapes the array (n,) to (n,1) because default is (1,n)
X = X.reshape(X.size,1)
y = np.array([x[1] for x in data])
y = y.reshape(y.size,1)

#Visualize the data.
plt.plot(X,y, "b.")
plt.title("Plot of data")
plt.xlabel("x1")
plt.ylabel("y")
plt.show()
# Out:
# A line  could not be parsed

# %%
iterations = 100
learn_rate = 0.01
#Initialize theta to some values
theta = np.random.randn(2,1) #Initialize our theta to some random normal distribution.
X_b = np.c_[np.ones((X.shape[0], X.shape[1] )), X] #Append ones to X to enable bias calculation
powv = np.vectorize(pow) #Numpy requires vectorization of functions

cost = []
for iteration in range(iterations): 
    delta = 2/X.size * X_b.T.dot(X_b.dot(theta)-y) #This is the derivative of our MSE error
    theta = theta - learn_rate*delta #We change our parameters based on our learn rate and derivative
    cost.append(pow((X_b.dot(theta)-y),2).mean()) #We log the cost so we can see the change

# %%
#Plot cost curve
plt.semilogx(range(iterations), cost)
plt.title("Cost curve")
plt.xlabel("Iterations")
plt.ylabel("Cost")
plt.grid()
plt.show()

# %%
#Make the prediction
X_test = np.array(([5],[22.5]))  #We create two points
X_test_b = np.c_[np.ones((2,1)), X_test] #We add the boas
yHat = X_test_b.dot(theta) #We check the prediction for these two values. Since it's linear we just need 2 points

# %%
#Plot the data
plt.plot(X_test, yHat, "r-") #Red and line. This is our linear prediction
plt.plot(X, y, 'b.') #Blue and scatter. #These are our original points
plt.title("Linear regression of data")
plt.xlabel("x0")
plt.ylabel("x1")
plt.grid()
plt.show()

# %% [markdown]
#  # Logistic linear regression

# %%
data = parse_file("ex2data1.mat")
X = np.array([[x[0],x[1]] for x in data]) #We split up our data and parse it into X ndarray
y = np.array([x[2] for x in data]) #Do the same for y.
#Reshapes the array (n,) to (n,1) because default is (1,n)
y = y.reshape(y.shape[0],1)
# Out:
# A line  could not be parsed

# %%
#Visualize the space
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0],X[:,1],y) #Plot every value on graph
plt.show()

# %%
#Visualize the data
for i in range(X.shape[0]):
    if(y[i] == 0):
        plt.plot(X[i,0], X[i,1], 'b.') #Blue
    elif(y[i] == 1):
        plt.plot(X[i,0], X[i,1], 'r.') #Red
plt.title("Plot of data")
plt.xlabel("x0")
plt.ylabel("x1")
plt.grid()
plt.show()

# %%
#Define helper functions
def sigmoid(x):
    #if X is <0 then we do subtraction form because python cant handle large positive exponents
    if x < 0:
        return 1 - 1/(1 + math.exp(x))
    else:
        return(1/(1+ math.exp(-x)))

vsigmoid = np.vectorize(sigmoid) #Use np.vectorise so we can apply function to our vectorized parameters

def logistic_cost(X_b, theta, y):
    #We define our cost function
    #Using masks where np.log(0)
    ycost = (-y*ma.log(vsigmoid(X_b.dot(theta))).filled(0) - (1-y)*ma.log(1-vsigmoid(X_b.dot(theta))).filled(0))

    cost = ycost.mean() #We take the mean of the cost so we can record the value.
    return(cost)
def threshold(p): #The threshold of our probability converted to prediction.
    if(p>0.5):
        return(1)
    elif(p<0.5):
        return(0)
vthreshold = np.vectorize(threshold)

# %%
#Apply polynomials and normalize.
poly = PolynomialFeatures(5, include_bias = False) #We generate polynomials of the form [1, a, b, a^2, ab, b^2].
X_poly = poly.fit_transform(X) #Transform our input data to these polynomial features
X_poly = scale(X_poly) #We normalize our inputs using the difference to mean / std dev

# %%
#Logistic regression
iterations = 50000
learn_rate = 0.1
#Initialize theta to some values
X_b = np.c_[np.ones((X_poly.shape[0],1)), X_poly] #We apply ones to account for bias
theta = np.random.randn(X_b.shape[1],1) #Initialize theta to some random normal distribution

cost = []
for iteration in range(iterations):
    delta = 1/X_poly.shape[0] * X_b.T.dot( vsigmoid(X_b.dot(theta)) -y ) #Calculate the gradient
    theta = theta - learn_rate*delta #Change theta based on our gradient and learn rate
    cost.append(logistic_cost(X_b,theta,y)) #Store the cost for tracking purposes

# %%
#Plot cost curve
plt.semilogx(range(iterations), cost)
plt.title("Cost curve")
plt.xlabel("Iterations")
plt.ylabel("Cost")
plt.grid()
plt.show()

# %%
x0 = np.linspace(X[:,0].min(0),X[:,0].max(0), num = 100) #Create 100 data points between max and min.
x1 = np.linspace(X[:,1].min(0),X[:,1].max(0), num = 100)
x0, x1 = np.meshgrid(x0, x1) #Create a grid that consists of all combinations within the space
X_test = np.c_[x0.ravel(), x1.ravel()] #Flattens x0 and x1 so we can predict on them
poly = PolynomialFeatures(5, include_bias = False) #Feature enhancement to 5 terms
X_test = poly.fit_transform(X_test)
X_test = np.c_[np.ones((x0.ravel().shape[0],1)),X_test] #Add ones for bias term
X_test = scale(X_test) #We normalize our inputs using the difference to mean / std dev

yHat = vthreshold(vsigmoid(X_test.dot(theta))) #Predicts the y values
yHat = yHat.reshape(x0.shape) #Convert it back to our original prediction grid.

#Plot the contours
plt.contourf(x0,x1,yHat,cmap=mpl.colors.ListedColormap(['#7290c1', '#c18b72']))

#Visualize the data
for i in range(X.shape[0]):
    if(y[i] == 0):
        plt.plot(X[i,0], X[i,1], 'b.') #Blue
    elif(y[i] == 1):
        plt.plot(X[i,0], X[i,1], 'r.') #Red
plt.title("Polynomial Regularized logistic regression")
plt.xlabel("x0")
plt.ylabel("x1")
plt.grid()
plt.show()
# Out:
# (100, 100)

# %% [markdown]
# # Polynomial L2 Regularized logistic regression

# %%
#TODO: Place models into classes.
# class LinearRegression:
#     iterations
#     learn_rate
#     reg_lambda
#     def __init__(self, iterations=1000,learn_rate=0.01,reg_lambda=1):
#         self.iterations = iterations
#         self.learn_rate = learn_rate
#         self.reg_lambda = reg_lambda
# newLinearRegression = LinearRegression(iterations=5000)

# %%
data = parse_file("ex2data2.mat")
X = np.array([[x[0],x[1]] for x in data])
y = np.array([x[2] for x in data])
#Reshapes the array (n,) to (n,1) because default is (1,n)
y = y.reshape(y.shape[0],1)
# Out:
# A line  could not be parsed

# %%
#Visualize the space
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0],X[:,1],y)
plt.show()

# %%
#Visualize the data
for i in range(X.shape[0]):
    if(y[i] == 0):
        plt.plot(X[i,0], X[i,1], 'b.') #Blue
    elif(y[i] == 1):
        plt.plot(X[i,0], X[i,1], 'r.') #Red
        
plt.title("Plot of graph")
plt.xlabel("x0")
plt.ylabel("x1")
plt.grid()
plt.show()
plt.show()

# %%
#Create polynomial features
#Refrence from Sklearn docs
poly_count = 10
poly = PolynomialFeatures(poly_count, include_bias = False)
X_poly = poly.fit_transform(X)

# %%
#Logistic regression with regularization
iterations = 100000
learn_rate = 5
reg_lambda = 0.5
#Initialize theta to some values

X_b = np.c_[np.ones((X_poly.shape[0],1)), X_poly]
theta = np.random.randn(X_b.shape[1],1)

cost = []
for iteration in range(iterations):
    delta = 1/X_poly.shape[0] * X_b.T.dot( vsigmoid(X_b.dot(theta)) -y ) # Calculate delta 
    theta = theta - learn_rate*(delta + (reg_lambda/X_poly.shape[0]) * theta) #We apply L2 regularization here. 
    cost.append(logistic_cost(X_b,theta,y))

# %%
#Plot cost curve
plt.semilogx(range(iterations), cost)
plt.title("Cost curve")
plt.xlabel("Iterations")
plt.ylabel("Cost")
plt.grid()
plt.show()

# %%
x0 = np.linspace(int(X[:,0].min(0)),int(X[:,0].max(0)+1))
x1 = np.linspace(int(X[:,1].min(0)),int(X[:,1].max(0)+1))

x0, x1 = np.meshgrid(x0, x1)
X_test = np.c_[np.ones((x0.ravel().shape[0],1)),x0.ravel(), x1.ravel()]
print(X_test.shape)
# Out:
# (2500, 3)

# %%
x0 = np.linspace(X[:,0].min(0),X[:,0].max(0), num = 100)
x1 = np.linspace(X[:,1].min(0),X[:,1].max(0), num = 100)
x0, x1 = np.meshgrid(x0, x1)
X_test = np.c_[x0.ravel(), x1.ravel()]
poly = PolynomialFeatures(poly_count, include_bias = False)
X_test = poly.fit_transform(np.c_[x0.ravel(),x1.ravel()])
X_test = np.c_[np.ones((x0.ravel().shape[0],1)),X_test]

yHat = vthreshold(vsigmoid(X_test.dot(theta)))
yHat = yHat.reshape(x0.shape)

plt.contourf(x0,x1,yHat,cmap=mpl.colors.ListedColormap(['#7290c1', '#c18b72']))

#Visualize the data
for i in range(X.shape[0]):
    if(y[i] == 0):
        plt.plot(X[i,0], X[i,1], 'b.') #Blue
    elif(y[i] == 1):
        plt.plot(X[i,0], X[i,1], 'r.') #Red
plt.title("Polynomial Regularized logistic regression" )
plt.xlabel("x0")
plt.ylabel("x1")
plt.grid()
plt.show()
